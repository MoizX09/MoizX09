# %%
message = "Hello Guys"

n = 100

for x in range(n):
    print(message)
# Out:
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# Hello Guys
# ...
